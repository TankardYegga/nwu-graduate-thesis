# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import MultipleLocator, FormatStrFormatter 
font_set = FontProperties(fname='/usr/share/fonts/STKAITI.TTF',size=15)
import matplotlib

plt.rcParams['figure.figsize'] = (12.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False     
# 设置标题大小
plt.rcParams['font.size'] = '16'
#解决画多幅图时出现图形部分重叠
fig = plt.figure()

matplotlib.rcParams.update(
{
'text.usetex': False,
'font.family': 'stixgeneral',
'mathtext.fontset': 'stix',
}
)

# %%
names = range(0,20,1)

names = [str(x)+"i" for x in list(names)]

print(names)
# x = range(len(names))
x = names
# y=[pow(10,i) for i in range(-5,1)]

# 可以用numpy的矩阵或者list直接赋值给abc，例如一个一行N列的矩阵matrix，a=matrix
a=[0.02083,0.00974,0.00974,0.00333,0.01091,0.02365,0.07986,0.3069,0.44674,0.64103,0.79791,0.79618,0.89333,0.87147,0.86174,0.90221,0.84588,0.87633,0.84641,0.86218]
b=[0.03147,0.01071,0.03448,0.08553,0.20064,0.4386,0.72973,0.77663,0.84775,0.85473,0.86624,0.94983,0.98276,1,1,1,1,1,1,1]
c=[0.96711,0.93269,0.93559,0.95254,0.91892,0.96181,0.95255,0.97163,0.9402,0.96949,0.96233,0.93972,0.96516,0.94237,0.95302,0.92593,0.94904,0.9614,0.93464,0.95364]

# linestyle: 实线-虚线-- 点线：点横线-. 
      
plt.plot(x, a,linestyle='-',marker='s',label=u'Lisa')
plt.plot(x, b, linestyle='-.',marker='+',label=u'Bb')
plt.plot(x, c,  linestyle=':',marker='*',label=u'Cc')

plt.grid(linestyle='-.')  

plt.ylim(0,1)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(x, names, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.00)

plt.xlabel('年龄1',fontproperties=font_set) #X轴标签
plt.ylabel("死亡率2",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'age_death' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')
# Out:
# ['0i', '1i', '2i', '3i', '4i', '5i', '6i', '7i', '8i', '9i', '10i', '11i', '12i', '13i', '14i', '15i', '16i', '17i', '18i', '19i']

# %%
herb_thresholds=[10,20,30,40,50]
recall_5 = [0.15803,	
            0.15703,
            0.16641,
            0.16822,	
            0.16715]
prec_5 = [0.22861,
0.22738,
0.23786,
0.24108,		
0.23833]
ndcg_5 = [0.33650,
0.33387,	
0.34376,	
0.34441	,
0.34655]

plt.grid(linestyle='-.')
plt.plot(herb_thresholds, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(herb_thresholds, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(herb_thresholds, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.35)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(herb_thresholds, herb_thresholds, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('herb_threshold',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra' + '草药域值对推荐效果的影响' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')

# %%
sge_num_layers = [1, 2 , 3]
recall_5 = [0.16822,
0.12053,
0.13293]

prec_5 = [
    0.24108,
0.17462,	
0.19362		
]

ndcg_5 = [
0.34441,	
0.31133,	
0.31662		
]

plt.grid(linestyle='-.')
plt.plot(sge_num_layers, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(sge_num_layers, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(sge_num_layers, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.35)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(sge_num_layers, sge_num_layers, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('sge_num_layer',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'SGE中卷积层的层数对推荐效果的影响' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')

# %%
hid_output_ratio = ["1/4", "2/4", "3/4", "4/4"]
recall_5 = [
    0.14296,		
0.14546,		
0.14546,		
0.14581		
]

prec_5 = [0.20610,		
0.21427,		
0.21427	,	
0.21423	]

ndcg_5 = [0.32716	,	
0.29746	,	
0.33155	,	
0.33240			]


plt.grid(linestyle='-.')
plt.plot(hid_output_ratio, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(hid_output_ratio, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(hid_output_ratio, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.35)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(hid_output_ratio, hid_output_ratio, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('hid_output_ratio',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'Bipartite-GCN中卷积层的隐藏层维度和输出层维度的关系对推荐效果的影响' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')

# %%
bipartite_gcn_num_layers = [1, 2 , 3]
recall_5 = [0.14581,		
0.12813	,	
0.05858	]

prec_5 = [
 0.21423,		
0.18581,		
0.08296			
]

ndcg_5 = [	
    0.33240,		
0.30722,		
0.14325		
]

plt.grid(linestyle='-.')
plt.plot(bipartite_gcn_num_layers, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(bipartite_gcn_num_layers, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(bipartite_gcn_num_layers, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.35)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(bipartite_gcn_num_layers, bipartite_gcn_num_layers, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('bipartite_gcn_num_layer',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'Bipartite-GCN中卷积层的层数对推荐效果的影响' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')

# %%
sympt_thresholds=[
    1,
2,
3,
5,
10,
15
]
recall_5 = [
0.13388,
0.16305,
0.15778,
0.16163,
0.16405,
0.16187,
]
prec_5 = [
0.19621,
0.23339,
0.22650,
0.23291,
0.23682,
0.23606,
]
ndcg_5 = [
0.32536,
0.34052,
0.32857,
0.33558,
0.34204,
0.33947,
]

plt.grid(linestyle='-.')
plt.plot(sympt_thresholds, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(sympt_thresholds, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(sympt_thresholds, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.35)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(sympt_thresholds, sympt_thresholds, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('sympt_threshold',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + '症状域值对推荐效果的影响' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')
plt.show()

# %%
loss_fn=[
  'SMGCN BPR',
  'SMGCN MultiLable'
]
recall_5 = [
  0.20375,
  0.20728
]
prec_5 = [
  0.27352,
  0.28675
]
ndcg_5 = [
 0.37428,
 0.38590
]

plt.grid(linestyle='-.')
plt.plot(loss_fn, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(loss_fn, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(loss_fn, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.40)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(loss_fn, loss_fn, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('loss_fn',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'SMGCN的推荐效果关于损失函数因子的变化曲线' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')
plt.show()

# %%
loss_fns=[
  'NGCF BPR',
  'NGCF MultiLable'
]
recall_5 = [
  0.20193,
0.20499
]
prec_5 = [
 0.26966,
0.28380
]
ndcg_5 = [
  0.36747,
  0.38221
]

plt.grid(linestyle='-.')
plt.plot(loss_fns, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(loss_fns, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(loss_fns, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.40)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(loss_fns, loss_fns, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('loss_fn',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'NGCF的推荐效果关于损失函数因子的变化曲线' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')
plt.show()

# %%
final_embed_dims=[
  64,
  128,
  256,
  512,
  1024,
  2048,
  4096
]
recall_5 = [
 0.20050,	
0.20027,	
0.20617,	
0.20914,		
0.20994,		
0.20937	,	
0.20480,
]
prec_5 = [
0.28057,		
0.27942,	
0.28504,		
0.28755,		
0.28643,	
0.28902,		
0.28344
]
ndcg_5 = [
  0.37703,		
0.37798,		
0.38344,			
0.38722	,	
0.38783	,	
0.38846	,	
0.38308,
]

plt.grid(linestyle='-.')
plt.plot(final_embed_dims, recall_5,  linestyle=':',marker='*',label=u'recall@5')
plt.plot(final_embed_dims, prec_5,  linestyle='-',marker='s',label=u'precision@5')
plt.plot(final_embed_dims, ndcg_5, linestyle='-.',marker='+',label=u'ndcg@5')

plt.ylim(0,0.40)    # 设置x轴的刻度从2到10
plt.grid(ls='--') 
plt.grid(True)
plt.legend()  # 让图例生效
plt.xticks(final_embed_dims, final_embed_dims, rotation=29)

plt.margins(0)
plt.subplots_adjust(bottom=0.15)

plt.xlabel('final_embed_dim',fontproperties=font_set) #X轴标签
plt.ylabel("score(0-1)",fontproperties=font_set) #Y轴标签

imgname = '/media/disk/exp/SMGCN/SMGCN/extra/' + 'SMGCN的推荐效果关于final_embed_dim因子的变化曲线' + '.png'
plt.savefig(imgname,bbox_inches = 'tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e47069e33b8e> in <module>
#      36 ]
#      37
# ---> 38 plt.grid(linestyle='-.')
#      39 plt.plot(final_embed_dims, recall_5,  linestyle=':',marker='*',label=u'recall@5')
#      40 plt.plot(final_embed_dims, prec_5,  linestyle='-',marker='s',label=u'precision@5')
#
# NameError: name 'plt' is not defined
